# %% [markdown]
# ## Отчет по заданию 1

# %% [markdown]
# #### Загрузил фотографии для обучения модели

# %% [markdown]
# ![image.png](attachment:5479265b-654b-4484-bb76-e6c74da427af.png)

# %% [markdown]
# #### Запустил создание модели и посмотрел "Точность на каждый класс" и "Матрицу ошибок"

# %% [markdown]
# ![image.png](attachment:777e05f5-5e5d-419c-8f26-0e7016fdf80a.png)

# %% [markdown]
# ![image.png](attachment:3c6b90a2-c223-4565-9d8f-f2df748c47fd.png)

# %% [markdown]
# #### Проверил работу модели загрузив хот-доги

# %% [markdown]
# ![image.png](attachment:4e851551-92b2-499d-a340-9d8e37398c73.png)

# %% [markdown]
# ![image.png](attachment:acad44fb-266c-4847-b75e-4c11113ffe9f.png)

# %% [markdown]
# #### Но модель может и ошибаться

# %% [markdown]
# ![image.png](attachment:a8023409-1c12-4ed3-a302-2d2a63fc784b.png)

# %% [markdown]
# #### Проверил работу модели загрузив не хот-доги

# %% [markdown]
# ![image.png](attachment:a0b4eb68-897a-4948-adee-2de2128325e5.png)

# %% [markdown]
# ![image.png](attachment:979be0b4-2018-4d86-92d4-10053ba31475.png)

# %% [markdown]
# #### Но модель тоже допускает ошибки

# %% [markdown]
# ![image.png](attachment:daf3ed87-1c57-44e3-ad3e-06a30351def3.png)

# %%
import os
from keras.models import load_model  
from PIL import Image, ImageOps 
import numpy as np

np.set_printoptions(suppress=True)

model = load_model("keras_Model.h5", compile=False)

class_names = open("labels.txt", "r").readlines()

data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

folder_path = "C:\\Users\\bikti\\Desktop\\hot_dog_validation"

# Iterate through all images in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    if os.path.isfile(file_path):
        try:
            image = Image.open(file_path).convert("RGB")

            size = (224, 224)
            image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

            image_array = np.asarray(image)

            normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

            data[0] = normalized_image_array

            prediction = model.predict(data)
            index = np.argmax(prediction)
            class_name = class_names[index]
            confidence_score = prediction[0][index]

            print(f"Image: {filename}")
            print(f"Class: {class_name[2:].strip()}")  
            print(f"Confidence Score: {confidence_score:.2f}\n")
        except Exception as e:
            print(f"Error processing file {filename}: {e}")
# Out:
# 1/1 [==============================] - 2s 2s/step
# Image: 133012.jpg
# Class: hot-dog
# Confidence Score: 0.99
#
# 1/1 [==============================] - 0s 52ms/step
# Image: 133015.jpg
# Class: no hot-dog
# Confidence Score: 0.57
#
# 1/1 [==============================] - 0s 55ms/step
# Image: 133245.jpg
# Class: hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 51ms/step
# Image: 135628.jpg
# Class: hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 57ms/step
# Image: 138933.jpg
# Class: hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 65ms/step
# Image: 138937.jpg
# Class: hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 52ms/step
# Image: 138969.jpg
# Class: hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 54ms/step
# Image: 139177.jpg
# Class: hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 52ms/step
# ...

# %%
import os
from keras.models import load_model  
from PIL import Image, ImageOps 
import numpy as np

np.set_printoptions(suppress=True)

model = load_model("keras_Model.h5", compile=False)

class_names = open("labels.txt", "r").readlines()

data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

folder_path = "C:\\Users\\bikti\\Desktop\\not_hot_dog_validation"

# Iterate through all images in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    if os.path.isfile(file_path):
        try:
            image = Image.open(file_path).convert("RGB")

            size = (224, 224)
            image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

            image_array = np.asarray(image)

            normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

            data[0] = normalized_image_array

            prediction = model.predict(data)
            index = np.argmax(prediction)
            class_name = class_names[index]
            confidence_score = prediction[0][index]

            print(f"Image: {filename}")
            print(f"Class: {class_name[2:].strip()}")  
            print(f"Confidence Score: {confidence_score:.2f}\n")
        except Exception as e:
            print(f"Error processing file {filename}: {e}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# Image: 13023.jpg
# Class: no hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 53ms/step
# Image: 13080.jpg
# Class: no hot-dog
# Confidence Score: 0.95
#
# 1/1 [==============================] - 0s 53ms/step
# Image: 13719.jpg
# Class: no hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 59ms/step
# Image: 13983.jpg
# Class: no hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 49ms/step
# Image: 14142.jpg
# Class: no hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 56ms/step
# Image: 14484.jpg
# Class: no hot-dog
# Confidence Score: 0.99
#
# 1/1 [==============================] - 0s 51ms/step
# Image: 15420.jpg
# Class: no hot-dog
# Confidence Score: 1.00
#
# 1/1 [==============================] - 0s 58ms/step
# Image: 15580.jpg
# Class: no hot-dog
# Confidence Score: 1.00
#
# ...

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ##### Собрал по 10 фотографии для 3 классов(машины, корабль, самолет)

# %% [markdown]
# ##### 1 класс - Car, 2 класс - Airplane, 3 класс - Ship

# %% [markdown]
# ![image.png](attachment:d08f82c0-e870-4b63-ab61-19a26cfba00e.png)

# %% [markdown]
# ### Точность на каждый класс

# %% [markdown]
# ![image.png](attachment:29dcb266-50aa-4da7-84e9-1af75ca1cb47.png)

# %% [markdown]
# ### Матрица ошибок

# %% [markdown]
# ![image.png](attachment:84dab2a1-c695-47fc-b32e-8a180ae94f58.png)

# %% [markdown]
# ### Проверил модель на не известных ей изображениях

# %% [markdown]
# ![image.png](attachment:1e332a5f-a061-4dd1-9166-4c6625303912.png)

# %% [markdown]
# ![image.png](attachment:41978088-5405-4186-a82f-fcfcac691559.png)

# %% [markdown]
# ![image.png](attachment:b62010ab-ed59-4973-9703-b49253031e80.png)

# %% [markdown]
# ![image.png](attachment:119ef730-a4b6-4616-8124-eddb5f5cac0e.png)

# %% [markdown]
# ##### Не известные изображения модель пытется распознать по форме и габаритам, например вытянутую ложку посчитало за самолет, а диван за машину

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

np.set_printoptions(suppress=True)

model = load_model("keras_ModelCar.h5", compile=False)

# Load the labels
class_names = open("labelsCar.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("C:\\Users\\bikti\\Downloads\\Без названия (1).jpg").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 2s 2s/step
# Class: Airplane
# Confidence Score: 0.7469324

# %% [markdown]
# # Задание 3

# %% [markdown]
# ![photo_2025-02-02_19-48-29.jpg](attachment:96b9cef2-af7b-4b6b-8e60-c2d268d4e4f7.jpg)

# %% [markdown]
# ![photo_2025-02-02_20-00-57.jpg](attachment:9ae72aa3-9985-458e-92f6-d1b391df46c8.jpg)

# %% [markdown]
# ![photo_2025-02-02_20-01-03.jpg](attachment:cf6ccf68-a504-464c-81df-9a1fd97b918e.jpg)
